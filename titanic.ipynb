# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load the data
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
combined = train.append(test)
combined = combined.reset_index().drop(['index'], axis=1)
train_original = train.copy()
test_original = test.copy()
combined.head()
# Out:
# /home/rob/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
# %matplotlib inline
#import matplotlib.pyplot as plt
#train.hist(bins=50, figsize=(20,15))
#plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer

pipeline_sex1 = ColumnTransformer([
        ("sex",  OrdinalEncoder(), ['Sex'])
    ])

combined['Sex'] = pipeline_sex1.fit_transform(combined)

# %%
def cabin_data(df):
    c = df['Cabin']
    c = c.str.extract(r'([a-zA-z]\d{0,3})', expand=False).fillna(value="U").str.split('(\d+)', expand=True)
    c = c.drop(2, axis=1)
    c[1] = c[1].fillna(value="0").astype(int).replace(0,np.nan)
    c[1] = c[1].replace(np.nan, 0)#c[1].max()/2)
    c = c.rename({0:'Deck', 1:'Room'}, axis=1)
    df = df.drop('Cabin', axis=1)
    df = pd.concat([df, c], axis=1)
    return df

def ticket_data(df):
    t = df['Ticket'].str.split(pat=r'(\d+$)', expand=True).sort_values(by=0, ascending=False)
    t[0] = t[0].str.replace(r"[^a-zA-Z\d]+", "").str.upper()
    t = t.replace({'CASOTON':'CA','SCAHBASLE':'SC', 'SCPARIS':'SC', 'SOTONO2':'SOTONOQ', 'STONO2':'SOTONOQ', 'SCA4':'A4', 'STONOQ':'SOTONOQ', 'SCAH':'SC', 'SCOW':'SC', 'SCA3':'SC', 'SOP':'SOPP'}).drop(2, axis=1)
    small_count = t[0].value_counts()[t[0].value_counts() < 20].keys()
    other_dict = {k:"Other code" for k in small_count}
    t = t.replace(other_dict)
    t = t.rename({0:'Ticket code', 1:'Ticket number'}, axis=1)
    df = df.drop('Ticket', axis=1)
    df = pd.concat([df, t], axis=1)
    df['Ticket number'] = df['Ticket number'].fillna(0).astype(int)
    df['Ticket code'] = df['Ticket code'].replace("", "Other code")
    return df

def name_data(df):
    df = df.join(df['Name'].str.split(pat=",", expand=True))
    df0 = df[1].str.split(pat=r'([a-zA-z]+\.)', expand=True, n=1).drop(0, axis=1)
    df = df.drop(1, axis=1).join(df0)
    df = df.rename(columns={0: 'Surname', 1: 'Title'})
    df1 = df[2].str.split(pat=r'(\([a-zA-z ]+\))', expand=True).drop(2, axis=1)
    df = df.drop(2, axis=1).join(df1)
    df = df.rename(columns={0: 'First name', 1: 'First name2'}).drop('Name', axis=1)
    df['First name'] = df['First name'].str.strip()
    df['First name2'] = df['First name2'].fillna("None")
    return df

def married(df):
    women = df[df['First name2'] != "None"][df['Sex'] ==0][df['SibSp'] > 0]
    men = df[df['Sex'] ==1][df['SibSp'] > 0][(df['Age'] >=16) | (df['Age'].isna())]
    men_women =pd.concat([women,men])
    married = (men_women.groupby(['Surname','First name']).size() == 2)
    df = df.set_index(['Surname', 'First name'])
    df['Spouse'] = married.astype('int')
    #df['Spouse'] = df['Spouse'].fillna(0)
    #df['Sibling'] = df['SibSp'] - df['Spouse']
    df = df.reset_index()
    age_fill = df[df['Spouse'] == 1].groupby(['Surname','First name'])['Age'].apply(lambda x: x.ffill().bfill())
    df.loc[age_fill.index]['Age']  = age_fill.values
    df['Age'].update(age_fill)
    #df = df.drop('SibSp', axis=1)
    df = df.drop('Spouse', axis=1)
    return df

if 0:
    def parents(df):
        children = df[df['Age']<16]
        children['Parents'] = children['Parch']
        children['Parch'] = 0
        children = children[['Parch', 'Parents']]

        df['Parents'] = 0
        df['Parch'].update(children['Parch'])
        df['Parents'].update(children['Parents'])
        return df

def ticket_range(df):
    train_tickets = df[df['Ticket number'].notnull()]['Ticket number'].astype(int)
    bins = np.arange(0,train_tickets.max() + 10, 10)
    train_tickets = pd.cut(train_tickets, bins)
    df['Ticket range'] = train_tickets.astype(str)
    return df

def family(df):
    family_count = df.groupby(['Surname', 'Ticket range']).size()
    df = df.reset_index()
    df = df.sort_values(['Surname']).set_index(['Surname', 'Ticket range', 'PassengerId'])
    df['Family count'] = family_count-1
    tindex= df[df['Family count'] >0]['Family count'].index
    count_update = df.loc[tindex.unique()]['Family count']
    df['Family count'].update(count_update)
    df['Family count2'] = df['Parch'] + df['SibSp']
    df['Family count'] = df[['Family count', 'Family count2']].max(axis=1)
    #df['Family count'] = df['Family count'] -  df['Parch'] - df['SibSp']
    df = df.drop('Family count2', axis=1)
    return df

def calculate_fare(df):
    df['Ticket number'] = df['Ticket number'].astype(int)
    tt = df.groupby('Ticket number').size()
    df = df.sort_values('Ticket number')
    df = df.set_index('Ticket number')
    df['Ticket count'] = tt
    df['Fare'] = df['Fare']/df['Ticket count']
    df = df.reset_index()
    df['Fare'] = df['Fare'].replace(0, np.nan)
    grouped = df.groupby('Pclass').Fare
    df['Fare'] = grouped.apply(lambda x: x.fillna(x.mean()))
    return df

# %%
combined = cabin_data(combined)
combined = ticket_data(combined)
combined = name_data(combined)
combined = married(combined)
combined = calculate_fare(combined)

#combined['Title'] = combined['Title'].replace({'Col.':'Military','Major.':'Military', 'Capt.':'Military', 'Countess.':'Nobility', 'Sir.':'Nobility', 'Mlle.':'Miss.', 'Ms.':'Miss.', 'Mme.':'Mrs.', 'Don.':'Mr.', 'Dona.':'Mrs.', 'Lady.':'Nobility', 'Jonkheer.':'Nobility'})
combined['Title'] = combined['Title'].replace({'Col.':'Other title','Major.':'Other title', 'Capt.':'Other title', 'Countess.':'Other title', 'Sir.':'Other title', 'Mlle.':'Miss.', 'Ms.':'Miss.', 'Mme.':'Mrs.', 'Don.':'Mr.', 'Dona.':'Mrs.', 'Lady.':'Other title', 'Jonkheer.':'Other title', 'Rev.':'Other title', 'Dr.':'Other title'})

grouped = combined.groupby(['Sex','Pclass', 'Title'])  
#grouped.Age.median()
combined.Age = grouped.Age.apply(lambda x: x.fillna(x.median()))

#combined = parents(combined)
combined = ticket_range(combined)
combined = family(combined)
# Out:
# /home/rob/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/rob/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
combined = combined.sort_values(by = 'PassengerId')
combined = combined.reset_index()

# %%
train_full_y = combined['Survived'][0:891]
test_passenger = combined['PassengerId'][891:]


combined = combined.drop(['Survived','Surname', 'Ticket range', 'PassengerId', 'First name', 'Ticket number', 'First name2', 'index',  'Parch', 'SibSp', 'Ticket code', 'Deck', 'Embarked', 'Title'], axis = 1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

cat_attribs = ['Title']
num_attribs = ["Pclass", 'Sex', 'Age', 'Room', 'Family count', 'Fare']

cat_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="most_frequent")),
        ("encode", OneHotEncoder()),
    ])

num_pipeline = Pipeline([
        ('std_scaler', StandardScaler()),
    ])

pipeline = ColumnTransformer([
        #("cat", cat_pipeline, cat_attribs),
        ("num", num_pipeline, num_attribs),

    ])

combined_prepared = pipeline.fit_transform(combined)

# %%
train_full_prepared = combined_prepared[0:891]
train_prepared = train_full_prepared[0:800]
val_prepared = train_full_prepared[800:891]
test_prepared = combined_prepared[891:]

train_y = train_full_y[0:800]
val_y = train_full_y[800:891]

# %%
from sklearn.ensemble import RandomForestClassifier

forest_reg = RandomForestClassifier(n_estimators=100, random_state=42)
forest_reg.fit(train_prepared, train_y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    # try 12 (3×4) combinations of hyperparameters
    {'n_estimators': [3, 10, 30, 100], 'max_features': [2, 4, 5]},
    # then try 6 (2×3) combinations with bootstrap set as False
    #{'bootstrap': [False], 'n_estimators': [3, 10, 30], 'max_features': [2, 3, 4]},
  ]

forest_reg = RandomForestClassifier(random_state=42)
# train across 5 folds, that's a total of (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='accuracy',
                           return_train_score=True)
grid_search.fit(train_prepared, train_y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators='warn', n_jobs=None,
#                                               oob_score=False, random_state=42,
#                                               verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid=[{'max_features': [2, 4, 5],
#                           'n_estimators': [3, 10, 30, 100]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='accuracy', verbose=0)

# %%
grid_search.best_params_
# Out:
# {'max_features': 2, 'n_estimators': 100}

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=2, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# 0.7893258426966292 {'max_features': 2, 'n_estimators': 3}
# 0.7893258426966292 {'max_features': 2, 'n_estimators': 10}
# 0.7935393258426966 {'max_features': 2, 'n_estimators': 30}
# 0.7991573033707865 {'max_features': 2, 'n_estimators': 100}
# 0.7907303370786517 {'max_features': 4, 'n_estimators': 3}
# 0.7907303370786517 {'max_features': 4, 'n_estimators': 10}
# 0.7935393258426966 {'max_features': 4, 'n_estimators': 30}
# 0.7921348314606742 {'max_features': 4, 'n_estimators': 100}
# 0.7752808988764045 {'max_features': 5, 'n_estimators': 3}
# 0.7780898876404494 {'max_features': 5, 'n_estimators': 10}
# 0.7935393258426966 {'max_features': 5, 'n_estimators': 30}
# 0.7935393258426966 {'max_features': 5, 'n_estimators': 100}

# %%
combined.shape
# Out:
# (1309, 11)

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {
        'n_estimators': randint(low=1, high=1000),
        'max_features': randint(low=1, high=7),
        "max_depth": [2, 3, 4, 5, None],
        'min_samples_split': randint(low=2, high=11),
        'min_samples_leaf': randint(low=1, high=11),
        "bootstrap": [True, False],
    }

rnd_search = RandomizedSearchCV(forest_reg, param_distributions=param_distribs,
                                n_iter=300, cv=5, scoring='accuracy', random_state=42)
rnd_search.fit(train_prepared, train_y)
# Out:
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     n_estimators=100,
#                                                     n_jobs=None,
#                                                     oob_score...
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f9ea92f1278>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f9ea92f1ef0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f9ea91fd6a0>},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='accuracy', verbose=0)

# %%
best_params = rnd_search.best_params_
print(best_params)
# Out:
# {'bootstrap': False, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 6, 'min_samples_split': 8, 'n_estimators': 133}

# %%
cvres = rnd_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# 0.825 {'bootstrap': True, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 615}
# 0.83375 {'bootstrap': False, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 100}
# 0.82625 {'bootstrap': False, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 344}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 460}
# 0.82875 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 475}
# 0.8175 {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 244}
# 0.7925 {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 647}
# 0.785 {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 316}
# 0.8025 {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 6, 'n_estimators': 898}
# 0.83 {'bootstrap': False, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 943}
# 0.79125 {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 388}
# 0.82 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 730}
# 0.8025 {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 462}
# 0.80875 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 720}
# 0.805 {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 10, 'n_estimators': 764}
# 0.82625 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 857}
# 0.775 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 63}
# 0.80625 {'bootstrap': True, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 419}
# 0.80625 {'bootstrap': True, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 10, 'min_samples_split': 8, 'n_estimators': 41}
# 0.7825 {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 48}
# 0.82625 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 987}
# 0.78875 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 769}
# 0.81375 {'bootstrap': True, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 207}
# 0.80375 {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 241}
# 0.825 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 231}
# 0.83 {'bootstrap': True, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 699}
# 0.82 {'bootstrap': True, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 646}
# 0.83375 {'bootstrap': False, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 348}
# 0.77625 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 9, 'min_samples_split': 10, 'n_estimators': 628}
# 0.79 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 7, 'n_estimators': 456}
# 0.79625 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 819}
# 0.8375 {'bootstrap': False, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 6, 'min_samples_split': 9, 'n_estimators': 233}
# 0.7775 {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 268}
# 0.82 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 625}
# 0.7925 {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 642}
# 0.80125 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 638}
# 0.825 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 416}
# 0.825 {'bootstrap': True, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 767}
# 0.8125 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 982}
# 0.7775 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 6, 'min_samples_split': 4, 'n_estimators': 660}
# 0.82625 {'bootstrap': False, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 511}
# 0.8225 {'bootstrap': True, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 936}
# 0.7925 {'bootstrap': False, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 9, 'min_samples_split': 10, 'n_estimators': 946}
# 0.81125 {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 572}
# 0.78375 {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 160}
# 0.7775 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 816}
# 0.83375 {'bootstrap': False, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 120}
# 0.83125 {'bootstrap': True, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 9, 'n_estimators': 420}
# 0.83125 {'bootstrap': False, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 99}
# 0.835 {'bootstrap': True, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 822}
# 0.82875 {'bootstrap': True, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 580}
# 0.8275 {'bootstrap': True, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 135}
# 0.7775 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 3, 'min_samples_split': 7, 'n_estimators': 375}
# 0.8325 {'bootstrap': False, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 6, 'min_samples_split': 9, 'n_estimators': 283}
# 0.81875 {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 453}
# 0.83125 {'bootstrap': False, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 192}
# 0.78625 {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 99}
# 0.77125 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 302}
# 0.82 {'bootstrap': True, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 191}
# 0.8275 {'bootstrap': True, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 793}
# 0.8175 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 626}
# 0.8075 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 3, 'n_estimators': 986}
# 0.78125 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 6, 'min_samples_split': 8, 'n_estimators': 477}
# 0.82125 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 408}
# 0.82625 {'bootstrap': True, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 36}
# 0.81125 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 471}
# 0.82875 {'bootstrap': True, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 959}
# 0.8 {'bootstrap': False, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 314}
# 0.78375 {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 783}
# 0.83125 {'bootstrap': False, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 264}
# 0.83375 {'bootstrap': True, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 196}
# 0.81875 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 936}
# 0.8275 {'bootstrap': False, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 657}
# 0.8225 {'bootstrap': False, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 8, 'n_estimators': 346}
# 0.81 {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 908}
# 0.78375 {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 751}
# 0.77125 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 272}
# 0.82625 {'bootstrap': True, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 76}
# 0.83 {'bootstrap': False, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 285}
# 0.82625 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 453}
# 0.80125 {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 612}
# 0.81875 {'bootstrap': True, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 837}
# 0.82 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 442}
# 0.77125 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 336}
# 0.79 {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 908}
# 0.83375 {'bootstrap': False, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 957}
# 0.8275 {'bootstrap': True, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 417}
# 0.8125 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 754}
# 0.7875 {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 115}
# 0.83 {'bootstrap': True, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 493}
# 0.82625 {'bootstrap': True, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 9, 'min_samples_split': 6, 'n_estimators': 761}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 9, 'min_samples_split': 9, 'n_estimators': 192}
# 0.78875 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 999}
# 0.81125 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 525}
# 0.79 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 881}
# 0.82 {'bootstrap': False, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 6, 'min_samples_split': 4, 'n_estimators': 177}
# 0.8275 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 9, 'min_samples_split': 4, 'n_estimators': 76}
# 0.83125 {'bootstrap': True, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 506}
# 0.82875 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 948}
# 0.83375 {'bootstrap': True, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 144}
# 0.82125 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 10, 'min_samples_split': 8, 'n_estimators': 398}
# 0.81875 {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 733}
# 0.8175 {'bootstrap': True, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 253}
# 0.82625 {'bootstrap': False, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 3, 'n_estimators': 795}
# 0.82 {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 339}
# 0.8275 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 657}
# 0.79375 {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 70}
# 0.83 {'bootstrap': False, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 6, 'min_samples_split': 8, 'n_estimators': 91}
# 0.81375 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 173}
# 0.8075 {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 476}
# 0.82 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 387}
# 0.825 {'bootstrap': True, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 409}
# 0.7775 {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 58}
# 0.82375 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 213}
# 0.8325 {'bootstrap': True, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 659}
# 0.7775 {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 526}
# 0.79875 {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 6, 'min_samples_split': 7, 'n_estimators': 259}
# 0.79125 {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 9, 'n_estimators': 358}
# 0.835 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 90}
# 0.81875 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 41}
# 0.82375 {'bootstrap': False, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 929}
# 0.83125 {'bootstrap': True, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 3, 'min_samples_split': 7, 'n_estimators': 594}
# 0.82625 {'bootstrap': True, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 798}
# 0.83125 {'bootstrap': False, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 801}
# 0.7825 {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 282}
# 0.79625 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 610}
# 0.8075 {'bootstrap': True, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 518}
# 0.77125 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 771}
# 0.83625 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 145}
# 0.79625 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 685}
# 0.83125 {'bootstrap': True, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 488}
# 0.8275 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 154}
# 0.81 {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 6, 'min_samples_split': 4, 'n_estimators': 891}
# 0.8175 {'bootstrap': False, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 6, 'min_samples_split': 6, 'n_estimators': 990}
# 0.80875 {'bootstrap': False, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 207}
# 0.82125 {'bootstrap': True, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 103}
# 0.83 {'bootstrap': False, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 98}
# 0.82375 {'bootstrap': False, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 249}
# 0.78125 {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 81}
# 0.81625 {'bootstrap': True, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 9, 'n_estimators': 401}
# 0.78375 {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 69}
# 0.82625 {'bootstrap': False, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 663}
# 0.82875 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 360}
# 0.795 {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 61}
# 0.8275 {'bootstrap': False, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 466}
# 0.82 {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 6, 'min_samples_split': 6, 'n_estimators': 838}
# 0.80875 {'bootstrap': True, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 3, 'n_estimators': 945}
# 0.8125 {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 9, 'min_samples_split': 10, 'n_estimators': 47}
# 0.825 {'bootstrap': True, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 257}
# 0.7925 {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 726}
# 0.82375 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 386}
# 0.81125 {'bootstrap': True, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 7}
# 0.82375 {'bootstrap': True, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 739}
# 0.7925 {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 10, 'min_samples_split': 8, 'n_estimators': 953}
# 0.81375 {'bootstrap': True, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 525}
# 0.78375 {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 233}
# 0.815 {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 623}
# 0.78375 {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 613}
# 0.83125 {'bootstrap': False, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 315}
# 0.8225 {'bootstrap': True, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 662}
# 0.82625 {'bootstrap': True, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 137}
# 0.81625 {'bootstrap': True, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 548}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 118}
# 0.8275 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 9, 'min_samples_split': 3, 'n_estimators': 847}
# 0.81 {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 410}
# 0.8375 {'bootstrap': False, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 532}
# 0.80625 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 805}
# 0.83 {'bootstrap': False, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 902}
# 0.815 {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 7, 'min_samples_split': 3, 'n_estimators': 13}
# 0.81875 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 329}
# 0.79125 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 419}
# 0.77125 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 376}
# 0.78625 {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 513}
# 0.8375 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 10, 'n_estimators': 229}
# 0.825 {'bootstrap': False, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 165}
# 0.81 {'bootstrap': True, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 601}
# 0.79125 {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 840}
# 0.81125 {'bootstrap': True, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 23}
# 0.78 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 503}
# 0.8325 {'bootstrap': False, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 198}
# 0.83125 {'bootstrap': False, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 15}
# 0.82875 {'bootstrap': True, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 923}
# 0.82125 {'bootstrap': False, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 997}
# 0.79625 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 834}
# 0.825 {'bootstrap': False, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 118}
# 0.83375 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 696}
# 0.83125 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 411}
# 0.81875 {'bootstrap': True, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 794}
# 0.83125 {'bootstrap': True, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 550}
# 0.81375 {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 10, 'min_samples_split': 9, 'n_estimators': 958}
# 0.77875 {'bootstrap': False, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 324}
# 0.8325 {'bootstrap': True, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 51}
# 0.79625 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 814}
# 0.835 {'bootstrap': True, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 983}
# 0.79625 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 936}
# 0.82875 {'bootstrap': True, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 202}
# 0.77125 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 803}
# 0.80625 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 386}
# 0.81625 {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 640}
# 0.82375 {'bootstrap': True, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 3, 'min_samples_split': 7, 'n_estimators': 664}
# 0.8325 {'bootstrap': True, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 5, 'min_samples_split': 9, 'n_estimators': 161}
# 0.83375 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 469}
# 0.78375 {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 148}
# 0.8375 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 327}
# 0.83 {'bootstrap': True, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 891}
# 0.82375 {'bootstrap': False, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 9, 'n_estimators': 19}
# 0.7775 {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 194}
# 0.81875 {'bootstrap': False, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 947}
# 0.80875 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 871}
# 0.80125 {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 380}
# 0.82625 {'bootstrap': True, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 833}
# 0.81625 {'bootstrap': True, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 761}
# 0.83375 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 604}
# 0.81 {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 814}
# 0.83375 {'bootstrap': True, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 469}
# 0.80125 {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 151}
# 0.82875 {'bootstrap': True, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 285}
# 0.805 {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 916}
# 0.79625 {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 119}
# 0.83 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 256}
# 0.7775 {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 500}
# 0.79875 {'bootstrap': False, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 9, 'n_estimators': 59}
# 0.7775 {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 526}
# 0.8075 {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 9, 'min_samples_split': 8, 'n_estimators': 201}
# 0.82375 {'bootstrap': False, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 727}
# 0.8325 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 42}
# 0.7775 {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 677}
# 0.81625 {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 7, 'min_samples_split': 6, 'n_estimators': 874}
# 0.82875 {'bootstrap': False, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 9, 'min_samples_split': 7, 'n_estimators': 731}
# 0.82 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 9, 'min_samples_split': 6, 'n_estimators': 455}
# 0.81875 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 6, 'n_estimators': 476}
# 0.81 {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 363}
# 0.83375 {'bootstrap': True, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 794}
# 0.82625 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 113}
# 0.835 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 623}
# 0.82 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 751}
# 0.82375 {'bootstrap': False, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 958}
# 0.8325 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 154}
# 0.82125 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 9, 'min_samples_split': 9, 'n_estimators': 17}
# 0.7925 {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 10, 'n_estimators': 39}
# 0.82 {'bootstrap': True, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 478}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 44}
# 0.8075 {'bootstrap': True, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 823}
# 0.82875 {'bootstrap': True, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 776}
# 0.8175 {'bootstrap': True, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 7, 'min_samples_split': 6, 'n_estimators': 374}
# 0.77875 {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 10, 'n_estimators': 877}
# 0.79 {'bootstrap': False, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 7, 'min_samples_split': 6, 'n_estimators': 86}
# 0.83 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 3, 'min_samples_split': 9, 'n_estimators': 498}
# 0.835 {'bootstrap': True, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 995}
# 0.815 {'bootstrap': False, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 526}
# 0.82625 {'bootstrap': True, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 805}
# 0.81375 {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 497}
# 0.82125 {'bootstrap': False, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 9, 'min_samples_split': 3, 'n_estimators': 161}
# 0.825 {'bootstrap': False, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 739}
# 0.8125 {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 3, 'n_estimators': 416}
# 0.83 {'bootstrap': False, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 5, 'n_estimators': 29}
# 0.77125 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 272}
# 0.805 {'bootstrap': False, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 359}
# 0.8 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 429}
# 0.8175 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 665}
# 0.77125 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 889}
# 0.82625 {'bootstrap': False, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 6, 'n_estimators': 61}
# 0.8225 {'bootstrap': True, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 6, 'min_samples_split': 8, 'n_estimators': 440}
# 0.835 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 711}
# 0.83125 {'bootstrap': False, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 861}
# 0.81875 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 3, 'n_estimators': 825}
# 0.77875 {'bootstrap': False, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 888}
# 0.82125 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 6, 'min_samples_split': 8, 'n_estimators': 689}
# 0.815 {'bootstrap': True, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 2, 'n_estimators': 573}
# 0.8025 {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 62}
# 0.82 {'bootstrap': True, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 6, 'min_samples_split': 9, 'n_estimators': 893}
# 0.78125 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 610}
# 0.79 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 9, 'min_samples_split': 4, 'n_estimators': 921}
# 0.8125 {'bootstrap': False, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 9, 'n_estimators': 537}
# 0.81125 {'bootstrap': True, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 124}
# 0.81875 {'bootstrap': True, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 10, 'min_samples_split': 3, 'n_estimators': 454}
# 0.83 {'bootstrap': True, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 114}
# 0.80125 {'bootstrap': False, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 568}
# 0.8125 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 216}
# 0.81 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 9, 'min_samples_split': 10, 'n_estimators': 693}
# 0.84 {'bootstrap': False, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 6, 'min_samples_split': 8, 'n_estimators': 133}
# 0.825 {'bootstrap': True, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 4, 'n_estimators': 31}
# 0.8 {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 927}
# 0.825 {'bootstrap': False, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 7, 'min_samples_split': 3, 'n_estimators': 224}
# 0.805 {'bootstrap': True, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 360}
# 0.81125 {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 326}
# 0.79 {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 989}
# 0.835 {'bootstrap': False, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 324}
# 0.79 {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 906}
# 0.7775 {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 10, 'min_samples_split': 9, 'n_estimators': 210}
# 0.825 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 948}
# 0.83 {'bootstrap': True, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 879}
# 0.81125 {'bootstrap': True, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 8, 'n_estimators': 538}
# 0.8175 {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 99}
# 0.79125 {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 687}
# 0.825 {'bootstrap': False, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 382}
# 0.83 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 955}
# 0.80625 {'bootstrap': False, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 507}
# 0.8175 {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 957}
# 0.77875 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 271}

# %%
feature_importances = rnd_search.best_estimator_.feature_importances_

# %%
#cat_encoder = pipeline.named_transformers_["cat"]
attributes =   num_attribs# + list(cat_encoder.named_steps["encode"].categories_[0])
#num_attribs + cat_encoder.named_steps["encode"].categories_[0]
#pipeline
#cat_pipeline.named_steps["encode"] # old solution
#cat_one_hot_attribs = list(cat_encoder.categories_[0])
#attributes = num_attribs + cat_one_hot_attribs
sorted(zip(feature_importances, attributes), reverse=True)
# Out:
# [(0.533955021355112, 'Sex'),
#  (0.1283097196233353, 'Pclass'),
#  (0.09752853603632744, 'Age'),
#  (0.08966673722501445, 'Fare'),
#  (0.08140376832923542, 'Room'),
#  (0.06913621743097538, 'Family count')]

# %%
val_predict = rnd_search.predict(val_prepared)

# %%
rnd_search.score(val_prepared, val_y)
# Out:
# 0.8571428571428571

# %%
forest_reg_full = RandomForestClassifier(max_depth=best_params['max_depth'], max_features=best_params['max_features'], n_estimators=best_params['n_estimators'], random_state=42)
forest_reg_full.fit(train_prepared, train_y)
forest_reg_full.score(train_prepared, train_y)
# Out:
# 0.87625

# %%
test_predict = rnd_search.predict(test_prepared)

# %%
test_submission = pd.DataFrame({'PassengerId':test_passenger.values, 'Survived':test_predict})

test_submission.to_csv('test_submission9.csv', index=False)

# %%
test_submission
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-f20dfb48c2ed> in <module>
# ----> 1 test_submission
#
# NameError: name 'test_submission' is not defined

# %%
import pandas as pd

# %%
tt = pd.read_csv("test_submission8.csv")
tt9 = pd.read_csv("test_submission9.csv")

# %%
aa = pd.read_csv("gender_submission.csv")

# %%
tt9['Survived'] = tt9['Survived'].astype(int)

# %%
aa.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1

# %%
tt9.to_csv('test_submission9.csv', index=False)

# %%
tt9 = pd.read_csv("test_submission9.csv")

# %%
tt9
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         0
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# 390         1282         1
# 391         1283         1
# 392         1284         0
# 393         1285         0
# 394         1286         0
# 395         1287         1
# 396         1288         0
# 397         1289         1
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         0
# 405         1297         1
# 406         1298         0
# 407         1299         0
# 408         1300         1
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 412         1304         1
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]

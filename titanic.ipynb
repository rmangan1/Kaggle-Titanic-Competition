# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Load the data
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")
combined = train.append(test)
combined = combined.reset_index().drop(['index'], axis=1)
train_original = train.copy()
test_original = test.copy()
combined.head()
# Out:
# /home/rob/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#     Age Cabin Embarked     Fare  \
# 0  22.0   NaN        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0   NaN        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0   NaN        S   8.0500
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
#
#    Pclass     Sex  SibSp  Survived            Ticket
# 0       3    male      1       0.0         A/5 21171
# 1       1  female      1       1.0          PC 17599
# 2       3  female      0       1.0  STON/O2. 3101282
# 3       1  female      1       1.0            113803
# 4       3    male      0       0.0            373450

# %%
# %matplotlib inline
#import matplotlib.pyplot as plt
#train.hist(bins=50, figsize=(20,15))
#plt.show()

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler


from sklearn.preprocessing import OrdinalEncoder
from sklearn.compose import ColumnTransformer

pipeline_sex1 = ColumnTransformer([
        ("sex",  OrdinalEncoder(), ['Sex'])
    ])

combined['Sex'] = pipeline_sex1.fit_transform(combined)

# %%
def cabin_data(df):
    c = df['Cabin']
    c = c.str.extract(r'([a-zA-z]\d{0,3})', expand=False).fillna(value="U").str.split('(\d+)', expand=True)
    c = c.drop(2, axis=1)
    c[1] = c[1].fillna(value="0").astype(int).replace(0,np.nan)
    c[1] = c[1].replace(np.nan, 0)#c[1].max()/2)
    c = c.rename({0:'Deck', 1:'Room'}, axis=1)
    df = df.drop('Cabin', axis=1)
    df = pd.concat([df, c], axis=1)
    return df

def ticket_data(df):
    t = df['Ticket'].str.split(pat=r'(\d+$)', expand=True).sort_values(by=0, ascending=False)
    t[0] = t[0].str.replace(r"[^a-zA-Z\d]+", "").str.upper()
    t = t.replace({'CASOTON':'CA','SCAHBASLE':'SC', 'SCPARIS':'SC', 'SOTONO2':'SOTONOQ', 'STONO2':'SOTONOQ', 'SCA4':'A4', 'STONOQ':'SOTONOQ', 'SCAH':'SC', 'SCOW':'SC', 'SCA3':'SC', 'SOP':'SOPP'}).drop(2, axis=1)
    small_count = t[0].value_counts()[t[0].value_counts() < 20].keys()
    other_dict = {k:"Other code" for k in small_count}
    t = t.replace(other_dict)
    t = t.rename({0:'Ticket code', 1:'Ticket number'}, axis=1)
    df = df.drop('Ticket', axis=1)
    df = pd.concat([df, t], axis=1)
    df['Ticket number'] = df['Ticket number'].fillna(0).astype(int)
    df['Ticket code'] = df['Ticket code'].replace("", "Other code")
    return df

def name_data(df):
    df = df.join(df['Name'].str.split(pat=",", expand=True))
    df0 = df[1].str.split(pat=r'([a-zA-z]+\.)', expand=True, n=1).drop(0, axis=1)
    df = df.drop(1, axis=1).join(df0)
    df = df.rename(columns={0: 'Surname', 1: 'Title'})
    df1 = df[2].str.split(pat=r'(\([a-zA-z ]+\))', expand=True).drop(2, axis=1)
    df = df.drop(2, axis=1).join(df1)
    df = df.rename(columns={0: 'First name', 1: 'First name2'}).drop('Name', axis=1)
    df['First name'] = df['First name'].str.strip()
    df['First name2'] = df['First name2'].fillna("None")
    return df

def married(df):
    women = df[df['First name2'] != "None"][df['Sex'] ==0][df['SibSp'] > 0]
    men = df[df['Sex'] ==1][df['SibSp'] > 0][(df['Age'] >=16) | (df['Age'].isna())]
    men_women =pd.concat([women,men])
    married = (men_women.groupby(['Surname','First name']).size() == 2)
    df = df.set_index(['Surname', 'First name'])
    df['Spouse'] = married.astype('int')
    df['Spouse'] = df['Spouse'].fillna(0)
    df['Sibling'] = df['SibSp'] - df['Spouse']
    df = df.reset_index()
    age_fill = df[df['Spouse'] == 1].groupby(['Surname','First name'])['Age'].apply(lambda x: x.ffill().bfill())
    df.loc[age_fill.index]['Age']  = age_fill.values
    df['Age'].update(age_fill)
    df = df.drop('SibSp', axis=1)
    #df = df.drop(['Spouse', 'Sibling'], axis=1)
    return df

def parents(df):
    children = df[df['Age']<16]
    children['Parents'] = children['Parch']
    children['Parch'] = 0
    children = children[['Parch', 'Parents']]

    df['Parents'] = 0
    df['Parch'].update(children['Parch'])
    df['Parents'].update(children['Parents'])
    return df

def ticket_range(df):
    train_tickets = df[df['Ticket number'].notnull()]['Ticket number'].astype(int)
    bins = np.arange(0,train_tickets.max() + 10, 10)
    train_tickets = pd.cut(train_tickets, bins)
    df['Ticket range'] = train_tickets.astype(str)
    return df

def family(df):
    family_count = df.groupby(['Surname', 'Ticket range']).size()
    df = df.reset_index()
    df = df.sort_values(['Surname']).set_index(['Surname', 'Ticket range', 'PassengerId'])
    df['Family count'] = family_count-1
    tindex= df[df['Family count'] >0]['Family count'].index
    count_update = df.loc[tindex.unique()]['Family count']
    df['Family count'].update(count_update)
    df['Family count2'] = df['Parch'] + df['Spouse'] + df['Parents'] + df['Sibling']
    df['Family count'] = df[['Family count', 'Family count2']].max(axis=1)
    #df['Family count'] = df['Family count'] -  df['Parch'] - df['Spouse'] - df['Parents'] - df['Sibling']
    df = df.drop('Family count2', axis=1)
    return df

def calculate_fare(df):
    df['Ticket number'] = df['Ticket number'].astype(int)
    tt = df.groupby('Ticket number').size()
    df = df.sort_values('Ticket number')
    df = df.set_index('Ticket number')
    df['Ticket count'] = tt
    df['Fare'] = df['Fare']/df['Ticket count']
    df = df.reset_index()
    df['Fare'] = df['Fare'].replace(0, np.nan)
    grouped = df.groupby('Pclass').Fare
    df['Fare'] = grouped.apply(lambda x: x.fillna(x.mean()))
    return df

def friends(df):
    df['Ticket count'] = df['Ticket count'] - df['Family count'] - 1
    df['Ticket count'] = df['Ticket count'].clip(lower=0)
    return df

# %%
combined = cabin_data(combined)
combined = ticket_data(combined)
combined = name_data(combined)
combined = married(combined)
combined = calculate_fare(combined)

#combined['Title'] = combined['Title'].replace({'Col.':'Military','Major.':'Military', 'Capt.':'Military', 'Countess.':'Nobility', 'Sir.':'Nobility', 'Mlle.':'Miss.', 'Ms.':'Miss.', 'Mme.':'Mrs.', 'Don.':'Mr.', 'Dona.':'Mrs.', 'Lady.':'Nobility', 'Jonkheer.':'Nobility'})
combined['Title'] = combined['Title'].replace({'Col.':'Other title','Major.':'Other title', 'Capt.':'Other title', 'Countess.':'Other title', 'Sir.':'Other title', 'Mlle.':'Miss.', 'Ms.':'Miss.', 'Mme.':'Mrs.', 'Don.':'Mr.', 'Dona.':'Mrs.', 'Lady.':'Other title', 'Jonkheer.':'Other title', 'Rev.':'Other title', 'Dr.':'Other title'})

grouped = combined.groupby(['Sex','Pclass', 'Title'])  
#grouped.Age.median()
combined.Age = grouped.Age.apply(lambda x: x.fillna(x.median()))

combined = parents(combined)
combined = ticket_range(combined)
combined = family(combined)
combined = friends(combined)
# Out:
# /home/rob/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/rob/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:40: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/rob/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /home/rob/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:58: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
combined = combined.sort_values(by = 'PassengerId')
combined = combined.reset_index()

# %%
combined[combined['Ticket count'] > 0]
# Out:
#             Surname            Ticket range  PassengerId  index  \
# 6          McCarthy      (17460.0, 17470.0]            7    367
# 20           Fynney    (239860.0, 239870.0]           21    812
# 31          Spencer      (17560.0, 17570.0]           32    395
# 50           Panula  (3101290.0, 3101300.0]           51   1290
# 52           Harper      (17570.0, 17580.0]           53    397
# 61            Icard    (113570.0, 113580.0]           62    702
# 72             Hood      (14870.0, 14880.0]           73    346
# 74             Bing        (1600.0, 1610.0]           75     27
# 79          Dowdell    (364510.0, 364520.0]           80   1151
# 109           Moran    (371100.0, 371110.0]          110   1203
# 110          Porter    (110460.0, 110470.0]          111    650
# 114         Attalah        (2620.0, 2630.0]          115     94
# 118          Baxter      (17550.0, 17560.0]          119    392
# 120         Hickman      (14870.0, 14880.0]          121    340
# 138            Osen        (7530.0, 7540.0]          139    249
# 139          Giglio      (17590.0, 17600.0]          140    410
# 145        Nicholls      (33110.0, 33120.0]          146    585
# 164          Panula  (3101290.0, 3101300.0]          165   1285
# 169            Ling        (1600.0, 1610.0]          170     31
# 179         Leonard                     nan          180      1
# 195         Lurette      (17560.0, 17570.0]          196    396
# 207        Albimona        (2690.0, 2700.0]          208    176
# 211         Cameron      (13520.0, 13530.0]          212    318
# 218         Bazzani      (11810.0, 11820.0]          219    288
# 226         Mellors          (750.0, 760.0]          227     15
# 256          Thorne      (17580.0, 17590.0]          257    405
# 257          Cherry    (110150.0, 110160.0]          258    643
# 258            Ward      (17750.0, 17760.0]          259    444
# 266          Panula  (3101290.0, 3101300.0]          267   1284
# 268          Graham      (17580.0, 17590.0]          269    401
# ...             ...                     ...          ...    ...
# 1108           Wick      (36920.0, 36930.0]         1109    617
# 1109        Widener    (113500.0, 113510.0]         1110    691
# 1119        Everett        (6210.0, 6220.0]         1120    231
# 1121          Sweet    (220840.0, 220850.0]         1122    751
# 1130        Douglas      (17760.0, 17770.0]         1131    464
# 1133        Spedden      (16960.0, 16970.0]         1134    355
# 1137         Karnes      (13530.0, 13540.0]         1138    324
# 1161       McCaffry      (13040.0, 13050.0]         1162    304
# 1197        Allison    (113780.0, 113790.0]         1198    719
# 1199           Hays      (12740.0, 12750.0]         1200    297
# 1205          White      (17750.0, 17760.0]         1206    460
# 1207        Spencer      (17560.0, 17570.0]         1208    394
# 1215       Kreuchen      (24150.0, 24160.0]         1216    510
# 1218     Rosenshine      (17580.0, 17590.0]         1219    404
# 1221         Davies      (33110.0, 33120.0]         1222    584
# 1229        Denbury      (31020.0, 31030.0]         1230    570
# 1234        Cardeza      (17750.0, 17760.0]         1235    443
# 1240       Walcroft      (13520.0, 13530.0]         1241    317
# 1243         Dibden      (14870.0, 14880.0]         1244    341
# 1244         Herman    (220840.0, 220850.0]         1245    750
# 1258     Riihivouri  (3101290.0, 3101300.0]         1259   1288
# 1262         Wilson      (16960.0, 16970.0]         1263    351
# 1263          Ismay    (112050.0, 112060.0]         1264    670
# 1266          Bowen      (17600.0, 17610.0]         1267    430
# 1276         Herman    (220840.0, 220850.0]         1277    754
# 1281          Payne      (12740.0, 12750.0]         1282    296
# 1283         Abbott        (2670.0, 2680.0]         1284    145
# 1291        Bonnell      (36920.0, 36930.0]         1292    616
# 1298        Widener    (113500.0, 113510.0]         1299    692
# 1305  Oliva y Ocana      (17750.0, 17760.0]         1306    455
#
#       Ticket number                   First name   Age Embarked        Fare  \
# 6             17463                    Timothy J  54.0        S   25.931250
# 20           239865                     Joseph J  35.0        S   13.000000
# 31            17569             William Augustus  57.0        C   48.840267
# 50          3101295                   Juha Niilo   7.0        S    5.669643
# 52            17572                Henry Sleeper  49.0        C   25.576400
# 61           113572                       Amelie  38.0      NaN   40.000000
# 72            14879                   Ambrose Jr  21.0        S   10.500000
# 74             1601                          Lee  32.0        S    7.061975
# 79           364516                    Elizabeth  30.0        S    6.237500
# 109          371110                       Bertha  18.0        Q    8.050000
# 110          110465           Walter Chamberlain  47.0        S   26.000000
# 114            2627                       Malake  17.0        C    7.229150
# 118           17558                 Quigg Edmond  24.0        C   82.506933
# 120           14879               Stanley George  21.0        S   10.500000
# 138            7534                    Olaf Elon  16.0        S    4.608350
# 139           17593                       Victor  24.0        C   39.600000
# 145           33112               Joseph Charles  19.0        S    9.187500
# 164         3101295                 Eino Viljami   1.0        S    5.669643
# 169            1601                          Lee  28.0        S    7.061975
# 179               0                       Lionel  36.0        S    7.345171
# 195           17569                        Elise  58.0        C   48.840267
# 207            2699                Nassef Cassem  26.0        C    9.393750
# 211           13528                  Clear Annie  35.0        S   10.500000
# 218           11813                       Albina  32.0        C   38.145850
# 226             751                 William John  19.0        S    5.250000
# 256           17585            Gertrude Maybelle  45.0        C   39.600000
# 257          110152                       Gladys  30.0        S   28.833333
# 258           17755                         Anna  35.0        C  128.082300
# 266         3101295                Ernesti Arvid  16.0        S    5.669643
# 268           17582             William Thompson  58.0        S   51.154167
# ...             ...                          ...   ...      ...         ...
# 1108          36928               George Dennick  57.0        S   41.216675
# 1109         113503                George Dunton  50.0        C   42.300000
# 1119           6212                 Thomas James  40.5        S    7.550000
# 1121         220845             George Frederick  14.0        S   13.000000
# 1130          17761                Walter Donald  48.0        C   35.475000
# 1133          16966              Frederic Oakley  45.0        C   26.900000
# 1137          13534                      J Frank  22.0        S   10.500000
# 1161          13050               Thomas Francis  46.0        C   37.620850
# 1197         113781      Hudson Joshua Creighton  30.0        S   25.258333
# 1199          12749             Charles Melville  55.0        S   23.375000
# 1205          17760                  John Stuart  55.0        C   33.908325
# 1207          17569             William Augustus  57.0        C   48.840267
# 1215          24160                       Emilie  39.0        S   52.834375
# 1218          17585  George (Mr George Thorne")"  46.0        C   39.600000
# 1221          33112                  John Morgan  48.0        S    9.187500
# 1229          31029                      Herbert  25.0        S   10.500000
# 1234          17755     James Warburton Martinez  58.0        C  128.082300
# 1240          13528                       Nellie  31.0        S   10.500000
# 1243          14879                      William  18.0        S   10.500000
# 1244         220845                       Samuel  49.0        S   13.000000
# 1258        3101295   Susanna Juhantytar Sanni""  22.0        S    5.669643
# 1262          16966                  Helen Alice  31.0        C   26.900000
# 1263         112058                 Joseph Bruce  49.0        S   34.462282
# 1266          17608                  Grace Scott  45.0        C   37.482143
# 1276         220845                         Kate  24.0        S   13.000000
# 1281          12749              Vivian Ponsonby  23.0        S   23.375000
# 1283           2673                Eugene Joseph  13.0        S    5.062500
# 1291          36928                     Caroline  30.0        S   41.216675
# 1298         113503                George Dunton  50.0        C   42.300000
# 1305          17758                      Fermina  39.0        C   36.300000
#
#       Parch  ...  Deck   Room  Ticket code    Title  \
# 6         0  ...     E   46.0   Other code      Mr.
# 20        0  ...     U    0.0   Other code      Mr.
# 31        0  ...     B   78.0           PC     Mrs.
# 50        0  ...     U    0.0   Other code  Master.
# 52        0  ...     D   33.0           PC     Mrs.
# 61        0  ...     B   28.0   Other code    Miss.
# 72        0  ...     U    0.0   Other code      Mr.
# 74        0  ...     U    0.0   Other code      Mr.
# 79        0  ...     U    0.0   Other code    Miss.
# 109       0  ...     U    0.0   Other code    Miss.
# 110       0  ...     C  110.0   Other code      Mr.
# 114       0  ...     U    0.0   Other code    Miss.
# 118       1  ...     B   58.0           PC      Mr.
# 120       0  ...     U    0.0   Other code      Mr.
# 138       0  ...     U    0.0   Other code      Mr.
# 139       0  ...     B   86.0           PC      Mr.
# 145       1  ...     U    0.0           CA      Mr.
# 164       0  ...     U    0.0   Other code  Master.
# 169       0  ...     U    0.0   Other code      Mr.
# 179       0  ...     U    0.0   Other code      Mr.
# 195       0  ...     B   80.0           PC    Miss.
# 207       0  ...     U    0.0   Other code      Mr.
# 211       0  ...     U    0.0   Other code    Miss.
# 218       0  ...     D   15.0   Other code    Miss.
# 226       0  ...     U    0.0   Other code      Mr.
# 256       0  ...     U    0.0           PC     Mrs.
# 257       0  ...     B   77.0   Other code    Miss.
# 258       0  ...     U    0.0           PC    Miss.
# 266       1  ...     U    0.0   Other code      Mr.
# 268       1  ...     C  125.0           PC     Mrs.
# ...     ...  ...   ...    ...          ...      ...
# 1108      1  ...     U    0.0   Other code      Mr.
# 1109      1  ...     C   80.0   Other code     Mrs.
# 1119      0  ...     U    0.0           CA      Mr.
# 1121      0  ...     U    0.0   Other code      Mr.
# 1130      0  ...     C   86.0           PC     Mrs.
# 1133      1  ...     E   34.0   Other code      Mr.
# 1137      0  ...     U    0.0   Other code     Mrs.
# 1161      0  ...     C    6.0   Other code      Mr.
# 1197      2  ...     C   22.0   Other code      Mr.
# 1199      1  ...     B   69.0   Other code      Mr.
# 1205      0  ...     C   32.0           PC     Mrs.
# 1207      0  ...     B   78.0           PC      Mr.
# 1215      0  ...     U    0.0   Other code    Miss.
# 1218      0  ...     U    0.0           PC      Mr.
# 1221      2  ...     U    0.0           CA     Mrs.
# 1229      0  ...     U    0.0           CA      Mr.
# 1234      1  ...     B   51.0           PC     Mrs.
# 1240      0  ...     U    0.0   Other code    Miss.
# 1243      0  ...     U    0.0   Other code      Mr.
# 1244      2  ...     U    0.0   Other code      Mr.
# 1258      0  ...     U    0.0   Other code    Miss.
# 1262      0  ...     E   39.0   Other code    Miss.
# 1263      0  ...     B   52.0   Other code      Mr.
# 1266      0  ...     U    0.0           PC    Miss.
# 1276      2  ...     U    0.0   Other code    Miss.
# 1281      0  ...     B   24.0   Other code      Mr.
# 1283      0  ...     U    0.0           CA  Master.
# 1291      0  ...     C    7.0   Other code    Miss.
# 1298      1  ...     C   80.0   Other code      Mr.
# 1305      0  ...     C  105.0           PC     Mrs.
#
#                        First name2 Spouse Sibling Ticket count  Parents  \
# 6                             None    0.0     0.0          1.0        0
# 20                            None    0.0     0.0          1.0        0
# 31                 (Marie Eugenie)    1.0     0.0          1.0        0
# 50                            None    0.0     4.0          1.0        1
# 52                   (Myna Haxtun)    1.0     0.0          1.0        0
# 61                            None    0.0     0.0          1.0        0
# 72                            None    0.0     0.0          6.0        0
# 74                            None    0.0     0.0          7.0        0
# 79                            None    0.0     0.0          1.0        0
# 109                           None    0.0     1.0          1.0        0
# 110                           None    0.0     0.0          1.0        0
# 114                           None    0.0     0.0          1.0        0
# 118                           None    0.0     0.0          1.0        0
# 120                           None    0.0     2.0          4.0        0
# 138                           None    0.0     0.0          1.0        0
# 139                           None    0.0     0.0          1.0        0
# 145                           None    0.0     1.0          1.0        0
# 164                           None    0.0     4.0          1.0        1
# 169                           None    0.0     0.0          7.0        0
# 179                           None    0.0     0.0          3.0        0
# 195                           None    0.0     0.0          2.0        0
# 207                           None    0.0     0.0          1.0        0
# 211                           None    0.0     0.0          1.0        0
# 218                           None    0.0     0.0          1.0        0
# 226                           None    0.0     0.0          1.0        0
# 256                           None    0.0     0.0          1.0        0
# 257                           None    0.0     0.0          2.0        0
# 258                           None    0.0     0.0          3.0        0
# 266                           None    0.0     4.0          1.0        0
# 268                (Edith Junkins)    0.0     0.0          1.0        0
# ...                            ...    ...     ...          ...      ...
# 1108                          None    1.0     0.0          1.0        0
# 1109              (Eleanor Elkins)    1.0     0.0          2.0        0
# 1119                          None    0.0     0.0          1.0        0
# 1121                          None    0.0     0.0          4.0        0
# 1130               (Mahala Dutton)    1.0     0.0          1.0        0
# 1133                          None    1.0     0.0          2.0        0
# 1137              (Claire Bennett)    0.0     0.0          1.0        0
# 1161                          None    0.0     0.0          1.0        0
# 1197                          None    0.0     1.0          2.0        0
# 1199                          None    1.0     0.0          1.0        0
# 1205                 (Ella Holmes)    0.0     0.0          3.0        0
# 1207                          None    1.0     0.0          1.0        0
# 1215                          None    0.0     0.0          3.0        0
# 1218                          None    0.0     0.0          1.0        0
# 1221  (Elizabeth Agnes Mary White)    0.0     0.0          1.0        0
# 1229                          None    0.0     0.0          2.0        0
# 1234      (Charlotte Wardle Drake)    0.0     0.0          2.0        0
# 1240                          None    0.0     0.0          1.0        0
# 1243                          None    0.0     0.0          6.0        0
# 1244                          None    1.0     0.0          1.0        0
# 1258                          None    0.0     0.0          6.0        0
# 1262                          None    0.0     0.0          4.0        0
# 1263                          None    0.0     0.0          1.0        0
# 1266                          None    0.0     0.0          6.0        0
# 1276                          None    0.0     1.0          1.0        0
# 1281                          None    0.0     0.0          3.0        0
# 1283                          None    0.0     0.0          1.0        2
# 1291                          None    0.0     0.0          3.0        0
# 1298                          None    1.0     0.0          2.0        0
# 1305                          None    0.0     0.0          2.0        0
#
#       Family count
# 6              0.0
# 20             0.0
# 31             1.0
# 50             5.0
# 52             1.0
# 61             0.0
# 72             0.0
# 74             0.0
# 79             0.0
# 109            1.0
# 110            0.0
# 114            0.0
# 118            1.0
# 120            2.0
# 138            0.0
# 139            0.0
# 145            2.0
# 164            5.0
# 169            0.0
# 179            0.0
# 195            0.0
# 207            0.0
# 211            0.0
# 218            0.0
# 226            0.0
# 256            0.0
# 257            0.0
# 258            0.0
# 266            5.0
# 268            1.0
# ...            ...
# 1108           2.0
# 1109           2.0
# 1119           0.0
# 1121           0.0
# 1130           1.0
# 1133           2.0
# 1137           0.0
# 1161           0.0
# 1197           3.0
# 1199           2.0
# 1205           0.0
# 1207           1.0
# 1215           0.0
# 1218           0.0
# 1221           2.0
# 1229           0.0
# 1234           1.0
# 1240           0.0
# 1243           0.0
# 1244           3.0
# 1258           0.0
# 1262           0.0
# 1263           0.0
# 1266           0.0
# 1276           3.0
# 1281           0.0
# 1283           2.0
# 1291           0.0
# 1298           2.0
# 1305           0.0
#
# [202 rows x 23 columns]

# %%
train_full_y = combined['Survived'][0:891]
test_passenger = combined['PassengerId'][891:]


combined = combined.drop(['Survived','Surname', 'Ticket range', 'PassengerId', 'First name', 'Ticket number', 'First name2', 'index', 'Ticket code',  'Spouse'], axis = 1)

# %%
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

cat_attribs = ['Title', 'Deck', 'Embarked']
num_attribs = ["Pclass", 'Sex', 'Age', 'Room', 'Family count', 'Fare', 'Sibling', 'Parents', 'Parch', 'Ticket count']

cat_pipeline = Pipeline([
        ('imputer', SimpleImputer(strategy="most_frequent")),
        ("encode", OneHotEncoder()),
    ])

num_pipeline = Pipeline([
        #('std_scaler', StandardScaler()),
        ('minmax_scaler', StandardScaler()),
    ])

pipeline = ColumnTransformer([
        ("cat", cat_pipeline, cat_attribs),
        ("num", num_pipeline, num_attribs),

    ])

combined_prepared = pipeline.fit_transform(combined)

# %%
train_full_prepared = combined_prepared[0:891]
train_prepared = train_full_prepared[0:800]
val_prepared = train_full_prepared[800:891]
test_prepared = combined_prepared[891:]

train_y = train_full_y[0:800]
val_y = train_full_y[800:891]

# %%
from sklearn.ensemble import RandomForestClassifier

forest_reg = RandomForestClassifier(n_estimators=100, random_state=42)
forest_reg.fit(train_prepared, train_y)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
from sklearn.model_selection import GridSearchCV

param_grid = [
    # try 12 (3×4) combinations of hyperparameters
    {'n_estimators': [3, 10, 30, 100], 'max_features': [2, 4, 5]},
    # then try 6 (2×3) combinations with bootstrap set as False
    #{'bootstrap': [False], 'n_estimators': [3, 10, 30], 'max_features': [2, 3, 4]},
  ]

forest_reg = RandomForestClassifier(random_state=42)
# train across 5 folds, that's a total of (12+6)*5=90 rounds of training 
grid_search = GridSearchCV(forest_reg, param_grid, cv=5,
                           scoring='accuracy',
                           return_train_score=True)
grid_search.fit(train_prepared, train_y)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators='warn', n_jobs=None,
#                                               oob_score=False, random_state=42,
#                                               verbose=0, warm_start=False),
#              iid='warn', n_jobs=None,
#              param_grid=[{'max_features': [2, 4, 5],
#                           'n_estimators': [3, 10, 30, 100]}],
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='accuracy', verbose=0)

# %%
grid_search.best_params_
# Out:
# {'max_features': 4, 'n_estimators': 10}

# %%
grid_search.best_estimator_
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=4, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=42, verbose=0,
#                        warm_start=False)

# %%
cvres = grid_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# 0.7875 {'max_features': 2, 'n_estimators': 3}
# 0.80375 {'max_features': 2, 'n_estimators': 10}
# 0.80375 {'max_features': 2, 'n_estimators': 30}
# 0.79875 {'max_features': 2, 'n_estimators': 100}
# 0.81 {'max_features': 4, 'n_estimators': 3}
# 0.81875 {'max_features': 4, 'n_estimators': 10}
# 0.8125 {'max_features': 4, 'n_estimators': 30}
# 0.80875 {'max_features': 4, 'n_estimators': 100}
# 0.805 {'max_features': 5, 'n_estimators': 3}
# 0.8175 {'max_features': 5, 'n_estimators': 10}
# 0.81125 {'max_features': 5, 'n_estimators': 30}
# 0.8125 {'max_features': 5, 'n_estimators': 100}

# %%
combined.shape
# Out:
# (1309, 15)

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

param_distribs = {
        'n_estimators': randint(low=1, high=1000),
        'max_features': randint(low=1, high=11),
        "max_depth": [2, 3, 4, 5, None],
        'min_samples_split': randint(low=2, high=11),
        'min_samples_leaf': randint(low=1, high=11),
        "bootstrap": [True, False],
    }

rnd_search = RandomizedSearchCV(forest_reg, param_distributions=param_distribs,
                                n_iter=300, cv=5, scoring='accuracy', random_state=42)
rnd_search.fit(train_prepared, train_y)
# Out:
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     n_estimators=100,
#                                                     n_jobs=None,
#                                                     oob_score...
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f7cbf7aa390>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f7cbf856320>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f7cbf7bca90>},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='accuracy', verbose=0)

# %%
best_params = rnd_search.best_params_
print(best_params)
# Out:
# {'bootstrap': False, 'max_depth': None, 'max_features': 9, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 387}

# %%
cvres = rnd_search.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# 0.8325 {'bootstrap': True, 'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 122}
# 0.8275 {'bootstrap': True, 'max_depth': 4, 'max_features': 8, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 872}
# 0.8275 {'bootstrap': False, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 344}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 253}
# 0.705 {'bootstrap': False, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 876}
# 0.8375 {'bootstrap': True, 'max_depth': 5, 'max_features': 9, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 819}
# 0.8275 {'bootstrap': True, 'max_depth': None, 'max_features': 9, 'min_samples_leaf': 7, 'min_samples_split': 3, 'n_estimators': 388}
# 0.80625 {'bootstrap': True, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 346}
# 0.81875 {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 943}
# 0.8 {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 388}
# 0.82 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 730}
# 0.82375 {'bootstrap': False, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 462}
# 0.83 {'bootstrap': True, 'max_depth': 5, 'max_features': 9, 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 720}
# 0.815 {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 10, 'n_estimators': 764}
# 0.83625 {'bootstrap': False, 'max_depth': 5, 'max_features': 9, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 839}
# 0.80375 {'bootstrap': True, 'max_depth': 2, 'max_features': 8, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 593}
# 0.825 {'bootstrap': False, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 490}
# 0.825 {'bootstrap': True, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 840}
# 0.73875 {'bootstrap': False, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 7, 'min_samples_split': 8, 'n_estimators': 574}
# 0.82625 {'bootstrap': False, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 987}
# 0.80125 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 769}
# 0.82125 {'bootstrap': True, 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 207}
# 0.8275 {'bootstrap': True, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 241}
# 0.835 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 231}
# 0.82375 {'bootstrap': True, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 86}
# 0.82625 {'bootstrap': False, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 9, 'min_samples_split': 6, 'n_estimators': 646}
# 0.82625 {'bootstrap': False, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 8, 'n_estimators': 348}
# 0.70375 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 9, 'min_samples_split': 10, 'n_estimators': 628}
# 0.7975 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 7, 'n_estimators': 456}
# 0.81 {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 234}
# 0.82875 {'bootstrap': False, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 8, 'min_samples_split': 10, 'n_estimators': 692}
# 0.80625 {'bootstrap': True, 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 386}
# 0.80625 {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 9, 'n_estimators': 81}
# 0.77375 {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 855}
# 0.6975 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 53}
# 0.82125 {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 5, 'n_estimators': 439}
# 0.78375 {'bootstrap': True, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 6, 'min_samples_split': 9, 'n_estimators': 837}
# 0.82 {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 201}
# 0.82875 {'bootstrap': False, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 764}
# 0.8175 {'bootstrap': True, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 511}
# 0.83 {'bootstrap': True, 'max_depth': 5, 'max_features': 7, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 929}
# 0.82125 {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 473}
# 0.81125 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 572}
# 0.74375 {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 160}
# 0.80625 {'bootstrap': True, 'max_depth': 2, 'max_features': 9, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 816}
# 0.82625 {'bootstrap': False, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 120}
# 0.7875 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 422}
# 0.825 {'bootstrap': False, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 9, 'min_samples_split': 4, 'n_estimators': 153}
# 0.79625 {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 163}
# 0.83375 {'bootstrap': False, 'max_depth': None, 'max_features': 9, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 580}
# 0.82625 {'bootstrap': True, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 135}
# 0.70875 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 3, 'min_samples_split': 7, 'n_estimators': 375}
# 0.82875 {'bootstrap': False, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 6, 'min_samples_split': 9, 'n_estimators': 283}
# 0.8175 {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 453}
# 0.8275 {'bootstrap': False, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 192}
# 0.80625 {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 6, 'min_samples_split': 4, 'n_estimators': 892}
# 0.83375 {'bootstrap': True, 'max_depth': None, 'max_features': 8, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 607}
# 0.81125 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 928}
# 0.80125 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 735}
# 0.8125 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 626}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 104}
# 0.8075 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 8, 'n_estimators': 538}
# 0.825 {'bootstrap': True, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 825}
# 0.8275 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 9, 'n_estimators': 512}
# 0.82625 {'bootstrap': False, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 3, 'n_estimators': 834}
# 0.83125 {'bootstrap': False, 'max_depth': 4, 'max_features': 9, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 314}
# 0.8025 {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 783}
# 0.82375 {'bootstrap': False, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 9, 'n_estimators': 53}
# 0.8275 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 7, 'min_samples_split': 5, 'n_estimators': 774}
# 0.82125 {'bootstrap': True, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 820}
# 0.82 {'bootstrap': False, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 657}
# 0.83 {'bootstrap': False, 'max_depth': 4, 'max_features': 10, 'min_samples_leaf': 7, 'min_samples_split': 6, 'n_estimators': 474}
# 0.805 {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 751}
# 0.80375 {'bootstrap': False, 'max_depth': 2, 'max_features': 8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 272}
# 0.83375 {'bootstrap': True, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 76}
# 0.82125 {'bootstrap': False, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 285}
# 0.83 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 453}
# 0.82375 {'bootstrap': False, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 612}
# 0.83 {'bootstrap': True, 'max_depth': None, 'max_features': 7, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 837}
# 0.81625 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 442}
# 0.79375 {'bootstrap': False, 'max_depth': 2, 'max_features': 8, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 16}
# 0.75875 {'bootstrap': False, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 908}
# 0.78875 {'bootstrap': False, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 427}
# 0.82625 {'bootstrap': True, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 168}
# 0.825 {'bootstrap': False, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 35}
# 0.80625 {'bootstrap': True, 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 115}
# 0.835 {'bootstrap': True, 'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 493}
# 0.83375 {'bootstrap': True, 'max_depth': None, 'max_features': 8, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 277}
# 0.8 {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 6, 'n_estimators': 457}
# 0.8025 {'bootstrap': False, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 978}
# 0.81 {'bootstrap': True, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 7, 'min_samples_split': 8, 'n_estimators': 217}
# 0.71125 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 880}
# 0.83 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 396}
# 0.80125 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 9, 'min_samples_split': 8, 'n_estimators': 796}
# 0.82375 {'bootstrap': False, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 6, 'n_estimators': 69}
# 0.8375 {'bootstrap': True, 'max_depth': 5, 'max_features': 9, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 484}
# 0.80375 {'bootstrap': True, 'max_depth': 2, 'max_features': 7, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 398}
# 0.8175 {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 733}
# 0.79875 {'bootstrap': True, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 253}
# 0.83125 {'bootstrap': False, 'max_depth': None, 'max_features': 8, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 946}
# 0.79875 {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 422}
# 0.8175 {'bootstrap': True, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 657}
# 0.81 {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 252}
# 0.82875 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 39}
# 0.8025 {'bootstrap': False, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 476}
# 0.84125 {'bootstrap': False, 'max_depth': None, 'max_features': 9, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 387}
# 0.83 {'bootstrap': True, 'max_depth': 5, 'max_features': 9, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 824}
# 0.83125 {'bootstrap': True, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 10, 'min_samples_split': 6, 'n_estimators': 80}
# 0.835 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 659}
# 0.76375 {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 526}
# 0.8075 {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 6, 'min_samples_split': 7, 'n_estimators': 259}
# 0.80875 {'bootstrap': False, 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 972}
# 0.83 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 90}
# 0.79625 {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 740}
# 0.83 {'bootstrap': False, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 929}
# 0.8225 {'bootstrap': True, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 883}
# 0.83375 {'bootstrap': False, 'max_depth': None, 'max_features': 9, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 798}
# 0.82625 {'bootstrap': False, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 801}
# 0.74875 {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 282}
# 0.8075 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 610}
# 0.77375 {'bootstrap': True, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 518}
# 0.80375 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 771}
# 0.82625 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 145}
# 0.70625 {'bootstrap': True, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 446}
# 0.80375 {'bootstrap': True, 'max_depth': 2, 'max_features': 8, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 551}
# 0.79625 {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 6, 'min_samples_split': 7, 'n_estimators': 771}
# 0.74875 {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 6, 'min_samples_split': 6, 'n_estimators': 990}
# 0.83125 {'bootstrap': False, 'max_depth': 4, 'max_features': 9, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 207}
# 0.82875 {'bootstrap': True, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 422}
# 0.81375 {'bootstrap': False, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 98}
# 0.82 {'bootstrap': False, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 249}
# 0.8 {'bootstrap': False, 'max_depth': 2, 'max_features': 8, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 81}
# 0.82125 {'bootstrap': True, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 9, 'n_estimators': 401}
# 0.8 {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 546}
# 0.83 {'bootstrap': False, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 663}
# 0.82625 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 8, 'min_samples_split': 5, 'n_estimators': 360}
# 0.79125 {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 61}
# 0.8225 {'bootstrap': False, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 466}
# 0.82 {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 513}
# 0.805 {'bootstrap': True, 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 78}
# 0.82875 {'bootstrap': False, 'max_depth': None, 'max_features': 9, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 47}
# 0.75125 {'bootstrap': True, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 257}
# 0.79875 {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 726}
# 0.82 {'bootstrap': False, 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 365}
# 0.81375 {'bootstrap': False, 'max_depth': 4, 'max_features': 8, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 3}
# 0.81375 {'bootstrap': True, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 739}
# 0.80375 {'bootstrap': True, 'max_depth': 2, 'max_features': 7, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 953}
# 0.8225 {'bootstrap': True, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 25}
# 0.81125 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 9, 'min_samples_split': 3, 'n_estimators': 111}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 748}
# 0.82375 {'bootstrap': True, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 692}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 6, 'min_samples_split': 6, 'n_estimators': 377}
# 0.8325 {'bootstrap': True, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 582}
# 0.82875 {'bootstrap': True, 'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 759}
# 0.8275 {'bootstrap': True, 'max_depth': 4, 'max_features': 8, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 920}
# 0.81375 {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 118}
# 0.83125 {'bootstrap': True, 'max_depth': 4, 'max_features': 9, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 26}
# 0.83375 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 6, 'min_samples_split': 7, 'n_estimators': 836}
# 0.8075 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 140}
# 0.80625 {'bootstrap': True, 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 6, 'min_samples_split': 6, 'n_estimators': 894}
# 0.82375 {'bootstrap': True, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 690}
# 0.8175 {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 7, 'min_samples_split': 3, 'n_estimators': 13}
# 0.8175 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 329}
# 0.80375 {'bootstrap': True, 'max_depth': 2, 'max_features': 8, 'min_samples_leaf': 6, 'min_samples_split': 8, 'n_estimators': 419}
# 0.805 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 376}
# 0.765 {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 513}
# 0.83125 {'bootstrap': False, 'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 9, 'min_samples_split': 6, 'n_estimators': 270}
# 0.82625 {'bootstrap': False, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 851}
# 0.8175 {'bootstrap': True, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 9, 'min_samples_split': 10, 'n_estimators': 402}
# 0.83 {'bootstrap': False, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 575}
# 0.80625 {'bootstrap': True, 'max_depth': 2, 'max_features': 9, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 503}
# 0.83 {'bootstrap': False, 'max_depth': None, 'max_features': 8, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 39}
# 0.8275 {'bootstrap': True, 'max_depth': 4, 'max_features': 7, 'min_samples_leaf': 3, 'min_samples_split': 9, 'n_estimators': 554}
# 0.8125 {'bootstrap': False, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 923}
# 0.83375 {'bootstrap': False, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 997}
# 0.80125 {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 522}
# 0.83125 {'bootstrap': True, 'max_depth': 4, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 806}
# 0.8325 {'bootstrap': True, 'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 15}
# 0.83375 {'bootstrap': True, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 755}
# 0.83125 {'bootstrap': False, 'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 5, 'min_samples_split': 5, 'n_estimators': 11}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 6, 'min_samples_split': 7, 'n_estimators': 712}
# 0.82625 {'bootstrap': True, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 985}
# 0.82625 {'bootstrap': True, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 888}
# 0.70375 {'bootstrap': True, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 51}
# 0.8075 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 814}
# 0.83375 {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 983}
# 0.80625 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 936}
# 0.835 {'bootstrap': True, 'max_depth': None, 'max_features': 9, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 202}
# 0.805 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 803}
# 0.82875 {'bootstrap': True, 'max_depth': 5, 'max_features': 9, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 386}
# 0.79875 {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 182}
# 0.8025 {'bootstrap': False, 'max_depth': 2, 'max_features': 7, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 501}
# 0.70625 {'bootstrap': False, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 6, 'min_samples_split': 3, 'n_estimators': 469}
# 0.805 {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 148}
# 0.83625 {'bootstrap': False, 'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 769}
# 0.83625 {'bootstrap': False, 'max_depth': None, 'max_features': 7, 'min_samples_leaf': 3, 'min_samples_split': 9, 'n_estimators': 723}
# 0.80375 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 18}
# 0.81375 {'bootstrap': True, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 988}
# 0.82125 {'bootstrap': True, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 897}
# 0.835 {'bootstrap': False, 'max_depth': None, 'max_features': 7, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 800}
# 0.81125 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 87}
# 0.81125 {'bootstrap': True, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 833}
# 0.83375 {'bootstrap': True, 'max_depth': 4, 'max_features': 8, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 54}
# 0.83125 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 604}
# 0.815 {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 814}
# 0.8275 {'bootstrap': True, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 469}
# 0.82 {'bootstrap': False, 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 10, 'min_samples_split': 8, 'n_estimators': 673}
# 0.83 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 285}
# 0.79625 {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 1, 'min_samples_split': 6, 'n_estimators': 916}
# 0.8 {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 119}
# 0.83 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 256}
# 0.76125 {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 500}
# 0.8325 {'bootstrap': False, 'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 1, 'min_samples_split': 9, 'n_estimators': 59}
# 0.765 {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 526}
# 0.825 {'bootstrap': True, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 758}
# 0.82375 {'bootstrap': False, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 10, 'min_samples_split': 3, 'n_estimators': 727}
# 0.82875 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 42}
# 0.805 {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 677}
# 0.82125 {'bootstrap': True, 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 981}
# 0.81 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 268}
# 0.8075 {'bootstrap': True, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 922}
# 0.8325 {'bootstrap': True, 'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 363}
# 0.82375 {'bootstrap': True, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 4, 'n_estimators': 794}
# 0.8325 {'bootstrap': True, 'max_depth': None, 'max_features': 8, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 187}
# 0.82625 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 623}
# 0.81125 {'bootstrap': False, 'max_depth': None, 'max_features': 8, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 751}
# 0.825 {'bootstrap': False, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 958}
# 0.81625 {'bootstrap': True, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 3, 'n_estimators': 501}
# 0.80375 {'bootstrap': True, 'max_depth': 2, 'max_features': 8, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 217}
# 0.82875 {'bootstrap': True, 'max_depth': 4, 'max_features': 8, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 39}
# 0.8125 {'bootstrap': True, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 5, 'min_samples_split': 4, 'n_estimators': 478}
# 0.81375 {'bootstrap': False, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 957}
# 0.825 {'bootstrap': True, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 815}
# 0.83 {'bootstrap': False, 'max_depth': 4, 'max_features': 8, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 727}
# 0.77125 {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 10, 'n_estimators': 877}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 1, 'min_samples_split': 8, 'n_estimators': 794}
# 0.8225 {'bootstrap': True, 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 137}
# 0.825 {'bootstrap': True, 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 935}
# 0.825 {'bootstrap': True, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 526}
# 0.8075 {'bootstrap': True, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 6, 'n_estimators': 171}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 7, 'min_samples_split': 8, 'n_estimators': 527}
# 0.7975 {'bootstrap': False, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 397}
# 0.81 {'bootstrap': False, 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 739}
# 0.8225 {'bootstrap': False, 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 891}
# 0.81125 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 5, 'min_samples_split': 10, 'n_estimators': 272}
# 0.83375 {'bootstrap': False, 'max_depth': 5, 'max_features': 9, 'min_samples_leaf': 10, 'min_samples_split': 10, 'n_estimators': 359}
# 0.8 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 429}
# 0.82375 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 665}
# 0.8075 {'bootstrap': False, 'max_depth': 2, 'max_features': 5, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 889}
# 0.84125 {'bootstrap': False, 'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 939}
# 0.80375 {'bootstrap': False, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 8, 'n_estimators': 564}
# 0.83125 {'bootstrap': False, 'max_depth': 4, 'max_features': 8, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 885}
# 0.83875 {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 218}
# 0.80625 {'bootstrap': True, 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 3, 'min_samples_split': 9, 'n_estimators': 774}
# 0.83625 {'bootstrap': True, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 521}
# 0.8375 {'bootstrap': True, 'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 690}
# 0.8025 {'bootstrap': False, 'max_depth': 2, 'max_features': 8, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 998}
# 0.825 {'bootstrap': True, 'max_depth': None, 'max_features': 9, 'min_samples_leaf': 9, 'min_samples_split': 5, 'n_estimators': 910}
# 0.825 {'bootstrap': True, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 635}
# 0.84 {'bootstrap': False, 'max_depth': None, 'max_features': 9, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 738}
# 0.82375 {'bootstrap': False, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 8, 'min_samples_split': 10, 'n_estimators': 261}
# 0.8025 {'bootstrap': True, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 328}
# 0.84125 {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 37}
# 0.795 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 40}
# 0.8175 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 568}
# 0.825 {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 216}
# 0.79375 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 9, 'min_samples_split': 10, 'n_estimators': 693}
# 0.8275 {'bootstrap': False, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 6, 'n_estimators': 747}
# 0.825 {'bootstrap': True, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 3, 'min_samples_split': 8, 'n_estimators': 426}
# 0.82375 {'bootstrap': False, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 7, 'min_samples_split': 3, 'n_estimators': 356}
# 0.8275 {'bootstrap': False, 'max_depth': None, 'max_features': 7, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 233}
# 0.82375 {'bootstrap': True, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 3, 'min_samples_split': 7, 'n_estimators': 467}
# 0.825 {'bootstrap': False, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 989}
# 0.825 {'bootstrap': False, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 324}
# 0.8075 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 705}
# 0.82625 {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 270}
# 0.83375 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 3, 'min_samples_split': 5, 'n_estimators': 381}
# 0.8175 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 6, 'min_samples_split': 4, 'n_estimators': 459}
# 0.795 {'bootstrap': False, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 977}
# 0.83125 {'bootstrap': True, 'max_depth': None, 'max_features': 9, 'min_samples_leaf': 7, 'min_samples_split': 8, 'n_estimators': 797}
# 0.82375 {'bootstrap': True, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 22}
# 0.81875 {'bootstrap': True, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 9, 'n_estimators': 604}
# 0.83125 {'bootstrap': True, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 659}
# 0.83125 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 7, 'n_estimators': 527}
# 0.825 {'bootstrap': False, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 792}
# 0.82125 {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 605}
# 0.805 {'bootstrap': True, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 4, 'min_samples_split': 8, 'n_estimators': 387}
# 0.825 {'bootstrap': True, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 916}
# 0.8025 {'bootstrap': False, 'max_depth': 2, 'max_features': 7, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 740}
# 0.8025 {'bootstrap': True, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 6, 'min_samples_split': 6, 'n_estimators': 117}
# 0.7725 {'bootstrap': False, 'max_depth': 4, 'max_features': 1, 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 274}
# 0.8175 {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 102}
# 0.82625 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 3, 'min_samples_split': 9, 'n_estimators': 553}
# 0.8325 {'bootstrap': True, 'max_depth': 5, 'max_features': 9, 'min_samples_leaf': 6, 'min_samples_split': 7, 'n_estimators': 92}
# 0.81 {'bootstrap': False, 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 865}
# 0.70375 {'bootstrap': False, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 589}
# 0.81875 {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 7, 'min_samples_split': 3, 'n_estimators': 166}
# 0.83 {'bootstrap': True, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 106}
# 0.79625 {'bootstrap': True, 'max_depth': 5, 'max_features': 1, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 635}
# 0.80375 {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 9, 'min_samples_split': 8, 'n_estimators': 223}

# %%
feature_importances = rnd_search.best_estimator_.feature_importances_

# %%
cat_encoder = pipeline.named_transformers_["cat"]
attributes = list(cat_encoder.named_steps["encode"].categories_[0]) + num_attribs + list(cat_encoder.named_steps["encode"].categories_[1]) + list(cat_encoder.named_steps["encode"].categories_[2])
#num_attribs + cat_encoder.named_steps["encode"].categories_[0]
#pipeline
#cat_pipeline.named_steps["encode"] # old solution
#cat_one_hot_attribs = list(cat_encoder.categories_[0])
#attributes = num_attribs + cat_one_hot_attribs
sorted(zip(feature_importances, attributes), reverse=True)
# Out:
# [(0.2428517804308791, 'Mr.'),
#  (0.18820580662615258, 'D'),
#  (0.09168647117331129, 'T'),
#  (0.07502716823924176, 'C'),
#  (0.06796624982623711, 'E'),
#  (0.0637664788577669, 'Miss.'),
#  (0.05512176640705266, 'G'),
#  (0.0514885891613714, 'F'),
#  (0.04266283173683037, 'Mrs.'),
#  (0.031002586094844124, 'U'),
#  (0.022576243294612015, 'Parch'),
#  (0.01591653592916742, 'S'),
#  (0.008819915153618192, 'Other title'),
#  (0.008610613788224718, 'Master.'),
#  (0.007640954529707073, 'B'),
#  (0.004955552980938397, 'Q'),
#  (0.004804446039812118, 'A'),
#  (0.004749519687252143, 'C'),
#  (0.003977555990889725, 'Ticket count'),
#  (0.0035166618462716707, 'Family count'),
#  (0.0023885516318013296, 'Age'),
#  (0.0013026829820727405, 'Room'),
#  (0.0007505860870270558, 'Sex'),
#  (0.00013663766006647985, 'Pclass'),
#  (7.381384485167169e-05, 'Fare'),
#  (0.0, 'Sibling'),
#  (0.0, 'Parents')]

# %%
val_predict = rnd_search.predict(val_prepared)

# %%
rnd_search.score(val_prepared, val_y)
# Out:
# 0.8461538461538461

# %%
forest_reg_full = RandomForestClassifier(max_depth=best_params['max_depth'], max_features=best_params['max_features'], n_estimators=best_params['n_estimators'], random_state=42)
forest_reg_full.fit(train_prepared, train_y)
forest_reg_full.score(train_prepared, train_y)
# Out:
# 0.87375

# %%
param_distribs = {
        'n_estimators': randint(low=1, high=1000),
        'max_features': randint(low=1, high=11),
        "max_depth": [2, 3, 4, 5, None],
        'min_samples_split': randint(low=2, high=11),
        'min_samples_leaf': randint(low=1, high=11),
        "bootstrap": [True, False],
    }

rnd_search_full = RandomizedSearchCV(forest_reg, param_distributions=param_distribs,
                                n_iter=100, cv=5, scoring='accuracy')
rnd_search_full.fit(train_full_prepared, train_full_y)
# Out:
# RandomizedSearchCV(cv=5, error_score='raise-deprecating',
#                    estimator=RandomForestClassifier(bootstrap=True,
#                                                     class_weight=None,
#                                                     criterion='gini',
#                                                     max_depth=None,
#                                                     max_features='auto',
#                                                     max_leaf_nodes=None,
#                                                     min_impurity_decrease=0.0,
#                                                     min_impurity_split=None,
#                                                     min_samples_leaf=1,
#                                                     min_samples_split=2,
#                                                     min_weight_fraction_leaf=0.0,
#                                                     n_estimators=100,
#                                                     n_jobs=None,
#                                                     oob_score...
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f7cbf856240>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f7cbf8719b0>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_frozen object at 0x7f7cbfb4eac8>},
#                    pre_dispatch='2*n_jobs', random_state=None, refit=True,
#                    return_train_score=False, scoring='accuracy', verbose=0)

# %%
cvres = rnd_search_full.cv_results_
for mean_score, params in zip(cvres["mean_test_score"], cvres["params"]):
    print(mean_score, params)
# Out:
# 0.8316498316498316 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 327}
# 0.8271604938271605 {'bootstrap': True, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 3, 'min_samples_split': 3, 'n_estimators': 264}
# 0.7171717171717171 {'bootstrap': False, 'max_depth': 2, 'max_features': 1, 'min_samples_leaf': 9, 'min_samples_split': 3, 'n_estimators': 545}
# 0.8204264870931538 {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 5, 'min_samples_split': 7, 'n_estimators': 210}
# 0.8249158249158249 {'bootstrap': False, 'max_depth': 3, 'max_features': 7, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 662}
# 0.8013468013468014 {'bootstrap': False, 'max_depth': 2, 'max_features': 6, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 102}
# 0.8338945005611672 {'bootstrap': True, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 101}
# 0.8271604938271605 {'bootstrap': False, 'max_depth': 4, 'max_features': 9, 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 510}
# 0.8305274971941639 {'bootstrap': True, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 10, 'min_samples_split': 3, 'n_estimators': 431}
# 0.8271604938271605 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 10, 'min_samples_split': 9, 'n_estimators': 962}
# 0.8215488215488216 {'bootstrap': True, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 543}
# 0.8316498316498316 {'bootstrap': True, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 969}
# 0.8237934904601572 {'bootstrap': False, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 9, 'min_samples_split': 9, 'n_estimators': 639}
# 0.8282828282828283 {'bootstrap': True, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 208}
# 0.8092031425364759 {'bootstrap': False, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 7, 'n_estimators': 980}
# 0.8215488215488216 {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 155}
# 0.7542087542087542 {'bootstrap': False, 'max_depth': 3, 'max_features': 1, 'min_samples_leaf': 2, 'min_samples_split': 9, 'n_estimators': 292}
# 0.8125701459034792 {'bootstrap': False, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 9, 'min_samples_split': 7, 'n_estimators': 238}
# 0.8260381593714927 {'bootstrap': True, 'max_depth': 4, 'max_features': 6, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 530}
# 0.8316498316498316 {'bootstrap': True, 'max_depth': 5, 'max_features': 7, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 965}
# 0.8271604938271605 {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 2, 'min_samples_split': 7, 'n_estimators': 213}
# 0.8237934904601572 {'bootstrap': False, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 9, 'min_samples_split': 10, 'n_estimators': 345}
# 0.8092031425364759 {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 10, 'n_estimators': 584}
# 0.8204264870931538 {'bootstrap': True, 'max_depth': 5, 'max_features': 2, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 174}
# 0.8327721661054994 {'bootstrap': True, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 592}
# 0.8282828282828283 {'bootstrap': False, 'max_depth': 5, 'max_features': 7, 'min_samples_leaf': 8, 'min_samples_split': 3, 'n_estimators': 205}
# 0.8170594837261503 {'bootstrap': False, 'max_depth': 2, 'max_features': 10, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 6}
# 0.8338945005611672 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 57}
# 0.8002244668911336 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 9, 'n_estimators': 827}
# 0.8305274971941639 {'bootstrap': True, 'max_depth': 5, 'max_features': 9, 'min_samples_leaf': 4, 'min_samples_split': 7, 'n_estimators': 103}
# 0.8271604938271605 {'bootstrap': False, 'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 10, 'min_samples_split': 7, 'n_estimators': 469}
# 0.8305274971941639 {'bootstrap': True, 'max_depth': 4, 'max_features': 9, 'min_samples_leaf': 3, 'min_samples_split': 2, 'n_estimators': 478}
# 0.8237934904601572 {'bootstrap': False, 'max_depth': 3, 'max_features': 6, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 307}
# 0.813692480359147 {'bootstrap': False, 'max_depth': 4, 'max_features': 2, 'min_samples_leaf': 2, 'min_samples_split': 6, 'n_estimators': 680}
# 0.8215488215488216 {'bootstrap': False, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 7, 'min_samples_split': 2, 'n_estimators': 928}
# 0.7991021324354658 {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 40}
# 0.8103254769921436 {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 79}
# 0.8271604938271605 {'bootstrap': False, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 441}
# 0.8316498316498316 {'bootstrap': True, 'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 5, 'min_samples_split': 3, 'n_estimators': 757}
# 0.8282828282828283 {'bootstrap': False, 'max_depth': 4, 'max_features': 8, 'min_samples_leaf': 9, 'min_samples_split': 2, 'n_estimators': 266}
# 0.7991021324354658 {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 8, 'min_samples_split': 10, 'n_estimators': 287}
# 0.797979797979798 {'bootstrap': True, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 929}
# 0.8249158249158249 {'bootstrap': True, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 227}
# 0.797979797979798 {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 3, 'n_estimators': 203}
# 0.8092031425364759 {'bootstrap': False, 'max_depth': 2, 'max_features': 9, 'min_samples_leaf': 4, 'min_samples_split': 9, 'n_estimators': 353}
# 0.8181818181818182 {'bootstrap': False, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 2, 'min_samples_split': 3, 'n_estimators': 25}
# 0.8249158249158249 {'bootstrap': False, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 5, 'min_samples_split': 8, 'n_estimators': 951}
# 0.8327721661054994 {'bootstrap': True, 'max_depth': 4, 'max_features': 8, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 242}
# 0.8237934904601572 {'bootstrap': True, 'max_depth': 4, 'max_features': 5, 'min_samples_leaf': 9, 'min_samples_split': 7, 'n_estimators': 680}
# 0.8305274971941639 {'bootstrap': False, 'max_depth': None, 'max_features': 5, 'min_samples_leaf': 10, 'min_samples_split': 8, 'n_estimators': 517}
# 0.813692480359147 {'bootstrap': True, 'max_depth': 2, 'max_features': 9, 'min_samples_leaf': 10, 'min_samples_split': 9, 'n_estimators': 701}
# 0.8316498316498316 {'bootstrap': False, 'max_depth': None, 'max_features': 7, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 762}
# 0.8260381593714927 {'bootstrap': True, 'max_depth': None, 'max_features': 8, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 448}
# 0.8237934904601572 {'bootstrap': False, 'max_depth': 3, 'max_features': 8, 'min_samples_leaf': 4, 'min_samples_split': 3, 'n_estimators': 853}
# 0.8305274971941639 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 8, 'min_samples_split': 10, 'n_estimators': 841}
# 0.8260381593714927 {'bootstrap': True, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 8, 'min_samples_split': 10, 'n_estimators': 154}
# 0.8249158249158249 {'bootstrap': True, 'max_depth': 5, 'max_features': 9, 'min_samples_leaf': 8, 'min_samples_split': 9, 'n_estimators': 32}
# 0.835016835016835 {'bootstrap': True, 'max_depth': None, 'max_features': 7, 'min_samples_leaf': 3, 'min_samples_split': 7, 'n_estimators': 110}
# 0.8316498316498316 {'bootstrap': True, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 7, 'min_samples_split': 4, 'n_estimators': 383}
# 0.8237934904601572 {'bootstrap': True, 'max_depth': 3, 'max_features': 5, 'min_samples_leaf': 3, 'min_samples_split': 10, 'n_estimators': 542}
# 0.8226711560044894 {'bootstrap': False, 'max_depth': 4, 'max_features': 4, 'min_samples_leaf': 7, 'min_samples_split': 7, 'n_estimators': 285}
# 0.8316498316498316 {'bootstrap': True, 'max_depth': None, 'max_features': 8, 'min_samples_leaf': 2, 'min_samples_split': 10, 'n_estimators': 874}
# 0.8237934904601572 {'bootstrap': False, 'max_depth': 5, 'max_features': 6, 'min_samples_leaf': 2, 'min_samples_split': 4, 'n_estimators': 853}
# 0.7991021324354658 {'bootstrap': False, 'max_depth': 2, 'max_features': 3, 'min_samples_leaf': 9, 'min_samples_split': 4, 'n_estimators': 505}
# 0.8417508417508418 {'bootstrap': False, 'max_depth': None, 'max_features': 2, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 71}
# 0.813692480359147 {'bootstrap': True, 'max_depth': 3, 'max_features': 3, 'min_samples_leaf': 2, 'min_samples_split': 8, 'n_estimators': 33}
# 0.8294051627384961 {'bootstrap': False, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 9, 'min_samples_split': 4, 'n_estimators': 264}
# 0.8294051627384961 {'bootstrap': False, 'max_depth': 4, 'max_features': 8, 'min_samples_leaf': 6, 'min_samples_split': 8, 'n_estimators': 802}
# 0.797979797979798 {'bootstrap': True, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 10, 'min_samples_split': 6, 'n_estimators': 936}
# 0.8002244668911336 {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 464}
# 0.8282828282828283 {'bootstrap': False, 'max_depth': None, 'max_features': 7, 'min_samples_leaf': 9, 'min_samples_split': 5, 'n_estimators': 852}
# 0.8282828282828283 {'bootstrap': True, 'max_depth': None, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 358}
# 0.8035914702581369 {'bootstrap': False, 'max_depth': 2, 'max_features': 2, 'min_samples_leaf': 1, 'min_samples_split': 4, 'n_estimators': 758}
# 0.8114478114478114 {'bootstrap': False, 'max_depth': 2, 'max_features': 8, 'min_samples_leaf': 10, 'min_samples_split': 5, 'n_estimators': 776}
# 0.8125701459034792 {'bootstrap': False, 'max_depth': 2, 'max_features': 8, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 355}
# 0.8103254769921436 {'bootstrap': True, 'max_depth': 2, 'max_features': 9, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 906}
# 0.8069584736251403 {'bootstrap': True, 'max_depth': 2, 'max_features': 4, 'min_samples_leaf': 4, 'min_samples_split': 6, 'n_estimators': 643}
# 0.819304152637486 {'bootstrap': False, 'max_depth': 3, 'max_features': 4, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 981}
# 0.8226711560044894 {'bootstrap': False, 'max_depth': 3, 'max_features': 9, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 595}
# 0.8294051627384961 {'bootstrap': False, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 6, 'min_samples_split': 8, 'n_estimators': 158}
# 0.8249158249158249 {'bootstrap': True, 'max_depth': None, 'max_features': 6, 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 2}
# 0.8092031425364759 {'bootstrap': False, 'max_depth': None, 'max_features': 1, 'min_samples_leaf': 7, 'min_samples_split': 10, 'n_estimators': 663}
# 0.8080808080808081 {'bootstrap': True, 'max_depth': 2, 'max_features': 8, 'min_samples_leaf': 9, 'min_samples_split': 6, 'n_estimators': 592}
# 0.8327721661054994 {'bootstrap': False, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 5, 'min_samples_split': 6, 'n_estimators': 829}
# 0.8271604938271605 {'bootstrap': False, 'max_depth': 5, 'max_features': 10, 'min_samples_leaf': 5, 'min_samples_split': 2, 'n_estimators': 137}
# 0.8215488215488216 {'bootstrap': True, 'max_depth': 5, 'max_features': 3, 'min_samples_leaf': 8, 'min_samples_split': 8, 'n_estimators': 736}
# 0.8294051627384961 {'bootstrap': False, 'max_depth': 5, 'max_features': 5, 'min_samples_leaf': 8, 'min_samples_split': 7, 'n_estimators': 337}
# 0.8271604938271605 {'bootstrap': False, 'max_depth': 5, 'max_features': 4, 'min_samples_leaf': 9, 'min_samples_split': 5, 'n_estimators': 200}
# 0.8327721661054994 {'bootstrap': True, 'max_depth': None, 'max_features': 3, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 654}
# 0.8282828282828283 {'bootstrap': True, 'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 6, 'min_samples_split': 5, 'n_estimators': 416}
# 0.8226711560044894 {'bootstrap': False, 'max_depth': 5, 'max_features': 9, 'min_samples_leaf': 10, 'min_samples_split': 4, 'n_estimators': 939}
# 0.8125701459034792 {'bootstrap': False, 'max_depth': 2, 'max_features': 7, 'min_samples_leaf': 3, 'min_samples_split': 4, 'n_estimators': 223}
# 0.8305274971941639 {'bootstrap': False, 'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 6, 'min_samples_split': 10, 'n_estimators': 635}
# 0.8305274971941639 {'bootstrap': True, 'max_depth': 4, 'max_features': 7, 'min_samples_leaf': 6, 'min_samples_split': 2, 'n_estimators': 309}
# 0.8237934904601572 {'bootstrap': True, 'max_depth': 4, 'max_features': 3, 'min_samples_leaf': 7, 'min_samples_split': 6, 'n_estimators': 752}
# 0.8271604938271605 {'bootstrap': True, 'max_depth': None, 'max_features': 10, 'min_samples_leaf': 7, 'min_samples_split': 8, 'n_estimators': 764}
# 0.8215488215488216 {'bootstrap': False, 'max_depth': 5, 'max_features': 8, 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 55}
# 0.8260381593714927 {'bootstrap': True, 'max_depth': 3, 'max_features': 10, 'min_samples_leaf': 6, 'min_samples_split': 6, 'n_estimators': 595}
# 0.8058361391694725 {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 6, 'min_samples_split': 4, 'n_estimators': 629}
# 0.7991021324354658 {'bootstrap': True, 'max_depth': 3, 'max_features': 2, 'min_samples_leaf': 3, 'min_samples_split': 9, 'n_estimators': 441}

# %%
test_predict = rnd_search_full.predict(test_prepared).astype(int)

# %%
test_submission = pd.DataFrame({'PassengerId':test_passenger.values, 'Survived':test_predict})

test_submission.to_csv('test_submission12.csv', index=False)

# %%
tt = pd.read_csv("test_submission8.csv")
tt9 = pd.read_csv("test_submission10.csv")

# %%
aa = pd.read_csv("gender_submission.csv")

# %%
tt9['Survived'] = tt9['Survived'].astype(int)

# %%
tt9.to_csv('test_submission9.csv', index=False)

# %%
tt9 = pd.read_csv("test_submission9.csv")

# %%
tt9
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# 5            897         0
# 6            898         1
# 7            899         0
# 8            900         1
# 9            901         0
# 10           902         0
# 11           903         0
# 12           904         1
# 13           905         0
# 14           906         1
# 15           907         1
# 16           908         0
# 17           909         0
# 18           910         1
# 19           911         0
# 20           912         0
# 21           913         0
# 22           914         1
# 23           915         0
# 24           916         1
# 25           917         0
# 26           918         1
# 27           919         0
# 28           920         0
# 29           921         0
# ..           ...       ...
# 388         1280         0
# 389         1281         0
# 390         1282         1
# 391         1283         1
# 392         1284         0
# 393         1285         0
# 394         1286         0
# 395         1287         1
# 396         1288         0
# 397         1289         1
# 398         1290         0
# 399         1291         0
# 400         1292         1
# 401         1293         0
# 402         1294         1
# 403         1295         0
# 404         1296         0
# 405         1297         1
# 406         1298         0
# 407         1299         0
# 408         1300         1
# 409         1301         1
# 410         1302         1
# 411         1303         1
# 412         1304         1
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         1
#
# [418 rows x 2 columns]
